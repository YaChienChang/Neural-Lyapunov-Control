# %% [markdown]
# ## Learning Lyapunov function for Inverted Pendulum

# %%
# -*- coding: utf-8 -*-
from dreal import *
from Functions import *
import torch 
import torch.nn.functional as F
import numpy as np
import timeit 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Neural network model
# Building NN with random parameters for Lyapunov function and initializing parameters of NN controller to LQR solution
#
# LQR solution is obtained by minimizing the cost function J = ∫(xᵀQx + uᵀRu)dt, where Q is 2×2 identity matrix and R is 1×1 identity matrix

# %%
class Net(torch.nn.Module):
    
    def __init__(self,n_input,n_hidden,n_output,lqr):
        super(Net, self).__init__()
        torch.manual_seed(2)
        self.layer1 = torch.nn.Linear(n_input, n_hidden)
        self.layer2 = torch.nn.Linear(n_hidden,n_output)
        self.control = torch.nn.Linear(n_input,1,bias=False)
        self.control.weight = torch.nn.Parameter(lqr)

    def forward(self,x):
        sigmoid = torch.nn.Tanh()
        h_1 = sigmoid(self.layer1(x))
        out = sigmoid(self.layer2(h_1))
        u = self.control(x)
        return out,u

# %% [markdown]
# ## Dynamical system

# %%
def f_value(x,u):
    #Dynamics
    y = []
    G = 9.81  # gravity
    L = 0.5   # length of the pole 
    m = 0.15  # ball mass
    b = 0.1   # friction
    
    for r in range(0,len(x)): 
        f = [ x[r][1], 
              (m*G*L*np.sin(x[r][0])- b*x[r][1]) / (m*L**2)]
        y.append(f) 
    y = torch.tensor(y)
    y[:,1] = y[:,1] + (u[:,0]/(m*L**2))
    return y

# %% [markdown]
# ## Options

# %%
'''
For learning 
'''
N = 500             # sample size
D_in = 2            # input dimension
H1 = 6              # hidden dimension
D_out = 1           # output dimension
torch.manual_seed(10)  

x = torch.Tensor(N, D_in).uniform_(-6, 6)           
x_0 = torch.zeros([1, 2])

'''
For verifying 
'''
x1 = Variable("x1")
x2 = Variable("x2")
vars_ = [x1,x2]
G = 9.81 
l = 0.5  
m = 0.15
b = 0.1
config = Config()
config.use_polytope_in_forall = True
config.use_local_optimization = True
config.precision = 1e-2
epsilon = 0
# Checking candidate V within a ball around the origin (ball_lb ≤ sqrt(∑xᵢ²) ≤ ball_ub)
ball_lb = 0.5
ball_ub = 6

# %% [markdown]
# ## Learning and Falsification

# %%
out_iters = 0
valid = False
while out_iters < 2 and not valid: 
    start = timeit.default_timer()
    lqr = torch.tensor([[-23.58639732,  -5.31421063]])    # lqr solution
    model = Net(D_in,H1, D_out,lqr)
    L = []
    i = 0 
    t = 0
    max_iters = 2000
    learning_rate = 0.01
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    while i < max_iters and not valid: 
        V_candidate, u = model(x)
        X0,u0 = model(x_0)
        f = f_value(x,u)
        Circle_Tuning = Tune(x)
        # Compute lie derivative of V : L_V = ∑∂V/∂xᵢ*fᵢ
        L_V = torch.diagonal(torch.mm(torch.mm(torch.mm(dtanh(V_candidate),model.layer2.weight)\
                            *dtanh(torch.tanh(torch.mm(x,model.layer1.weight.t())+model.layer1.bias)),model.layer1.weight),f.t()),0)

        # With tuning
        Lyapunov_risk = (F.relu(-V_candidate)+ 1.5*F.relu(L_V+0.5)).mean()\
                    +2.2*((Circle_Tuning-6*V_candidate).pow(2)).mean()


        print(i, "Lyapunov Risk=",Lyapunov_risk.item()) 
        L.append(Lyapunov_risk.item())
        optimizer.zero_grad()
        Lyapunov_risk.backward()
        optimizer.step() 

        w1 = model.layer1.weight.data.numpy()
        w2 = model.layer2.weight.data.numpy()
        b1 = model.layer1.bias.data.numpy()
        b2 = model.layer2.bias.data.numpy()
        q = model.control.weight.data.numpy()

        # Falsification
        if i % 10 == 0:
            u_NN = (q.item(0)*x1 + q.item(1)*x2) 
            f = [ x2,
                 (m*G*l*sin(x1) + u_NN - b*x2) /(m*l**2)]

            # Candidate V
            z1 = np.dot(vars_,w1.T)+b1

            a1 = []
            for j in range(0,len(z1)):
                a1.append(tanh(z1[j]))
            z2 = np.dot(a1,w2.T)+b2
            V_learn = tanh(z2.item(0))

            print('===========Verifying==========')        
            start_ = timeit.default_timer() 
            result= CheckLyapunov(vars_, f, V_learn, ball_lb, ball_ub, config,epsilon)
            stop_ = timeit.default_timer() 

            if (result): 
                print("Not a Lyapunov function. Found counterexample: ")
                print(result)
                x = AddCounterexamples(x,result,10)
            else:  
                valid = True
                print("Satisfy conditions!!")
                print(V_learn, " is a Lyapunov function.")
            t += (stop_ - start_)
            print('==============================') 
        i += 1

    stop = timeit.default_timer()


    np.savetxt("w1.txt", model.layer1.weight.data, fmt="%s")
    np.savetxt("w2.txt", model.layer2.weight.data, fmt="%s")
    np.savetxt("b1.txt", model.layer1.bias.data, fmt="%s")
    np.savetxt("b2.txt", model.layer2.bias.data, fmt="%s")
    np.savetxt("q.txt", model.control.weight.data, fmt="%s")

    print('\n')
    print("Total time: ", stop - start)
    print("Verified time: ", t)
    
    out_iters+=1
# Out:
# (0, 'Lyapunov Risk=', 73.07493591308594)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-5.607981400644867165, -5.607370072610038392]
# x2 : [0.9742785792574937265, 0.974595727232512421]
# ==============================
# (1, 'Lyapunov Risk=', 60.24591827392578)
# (2, 'Lyapunov Risk=', 53.66139602661133)
# (3, 'Lyapunov Risk=', 49.358272552490234)
# (4, 'Lyapunov Risk=', 44.88718032836914)
# (5, 'Lyapunov Risk=', 40.768131256103516)
# (6, 'Lyapunov Risk=', 37.115272521972656)
# (7, 'Lyapunov Risk=', 33.89949417114258)
# (8, 'Lyapunov Risk=', 31.116905212402344)
# (9, 'Lyapunov Risk=', 28.676088333129883)
# (10, 'Lyapunov Risk=', 26.526872634887695)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.2044197886113856, -0.1944197886113855911]
# x2 : [0.5114223581404099273, 0.5214223581404099361]
# ==============================
# (11, 'Lyapunov Risk=', 24.382814407348633)
# (12, 'Lyapunov Risk=', 23.120990753173828)
# (13, 'Lyapunov Risk=', 21.971805572509766)
# (14, 'Lyapunov Risk=', 20.570842742919922)
# (15, 'Lyapunov Risk=', 19.09247589111328)
# (16, 'Lyapunov Risk=', 17.859468460083008)
# (17, 'Lyapunov Risk=', 17.244993209838867)
# (18, 'Lyapunov Risk=', 16.71889877319336)
# (19, 'Lyapunov Risk=', 15.553486824035645)
# (20, 'Lyapunov Risk=', 14.43832015991211)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-3.138771692090235099, -3.13833938152297609]
# x2 : [3.24188660064130918, 3.242203748616327985]
# ==============================
# (21, 'Lyapunov Risk=', 13.622417449951172)
# (22, 'Lyapunov Risk=', 13.13914966583252)
# (23, 'Lyapunov Risk=', 12.493324279785156)
# (24, 'Lyapunov Risk=', 11.783035278320312)
# (25, 'Lyapunov Risk=', 11.191756248474121)
# (26, 'Lyapunov Risk=', 10.758570671081543)
# (27, 'Lyapunov Risk=', 10.517389297485352)
# (28, 'Lyapunov Risk=', 10.158210754394531)
# (29, 'Lyapunov Risk=', 9.733505249023438)
# (30, 'Lyapunov Risk=', 9.414877891540527)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-3.000762730418810698, -3.000000000000000444]
# x2 : [4.589131198520812305, 4.589765494470849028]
# ==============================
# (31, 'Lyapunov Risk=', 9.123918533325195)
# (32, 'Lyapunov Risk=', 8.921039581298828)
# (33, 'Lyapunov Risk=', 8.738224029541016)
# (34, 'Lyapunov Risk=', 8.536759376525879)
# (35, 'Lyapunov Risk=', 8.318821907043457)
# (36, 'Lyapunov Risk=', 8.151825904846191)
# (37, 'Lyapunov Risk=', 8.017409324645996)
# (38, 'Lyapunov Risk=', 7.899451732635498)
# (39, 'Lyapunov Risk=', 7.78668737411499)
# (40, 'Lyapunov Risk=', 7.674485206604004)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.8829003900792969928, -0.8729003900792969839]
# x2 : [5.403087781184581218, 5.413087781184581004]
# ==============================
# (41, 'Lyapunov Risk=', 7.534648895263672)
# (42, 'Lyapunov Risk=', 7.468319416046143)
# (43, 'Lyapunov Risk=', 7.381703853607178)
# (44, 'Lyapunov Risk=', 7.288992881774902)
# (45, 'Lyapunov Risk=', 7.226158142089844)
# (46, 'Lyapunov Risk=', 7.157320976257324)
# (47, 'Lyapunov Risk=', 7.086617946624756)
# (48, 'Lyapunov Risk=', 7.036890983581543)
# (49, 'Lyapunov Risk=', 6.993537902832031)
# (50, 'Lyapunov Risk=', 6.9409942626953125)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-2.813964843750000444, -2.812500000000000444]
# x2 : [5.189376825607732613, 5.191105082385947256]
# ==============================
# (51, 'Lyapunov Risk=', 6.897098541259766)
# (52, 'Lyapunov Risk=', 6.8645148277282715)
# (53, 'Lyapunov Risk=', 6.834181785583496)
# (54, 'Lyapunov Risk=', 6.805849552154541)
# (55, 'Lyapunov Risk=', 6.779084205627441)
# (56, 'Lyapunov Risk=', 6.752728462219238)
# (57, 'Lyapunov Risk=', 6.728246688842773)
# (58, 'Lyapunov Risk=', 6.705953121185303)
# (59, 'Lyapunov Risk=', 6.684996604919434)
# (60, 'Lyapunov Risk=', 6.665390491485596)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.008319674465154466153, 0]
# x2 : [0.4999307782251396493, 0.506402105583381279]
# ==============================
# (61, 'Lyapunov Risk=', 7.1082563400268555)
# (62, 'Lyapunov Risk=', 7.09356164932251)
# (63, 'Lyapunov Risk=', 7.079835891723633)
# (64, 'Lyapunov Risk=', 7.0675740242004395)
# (65, 'Lyapunov Risk=', 7.055698394775391)
# (66, 'Lyapunov Risk=', 7.0452985763549805)
# (67, 'Lyapunov Risk=', 7.036086082458496)
# (68, 'Lyapunov Risk=', 7.028217792510986)
# (69, 'Lyapunov Risk=', 7.021757125854492)
# (70, 'Lyapunov Risk=', 7.014492034912109)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.876686975931951884, -0.8666869759319518751]
# x2 : [2.959843750000000551, 2.969843750000000338]
# ==============================
# (71, 'Lyapunov Risk=', 6.965163230895996)
# (72, 'Lyapunov Risk=', 6.96006965637207)
# (73, 'Lyapunov Risk=', 6.95589017868042)
# (74, 'Lyapunov Risk=', 6.949295520782471)
# (75, 'Lyapunov Risk=', 6.944174289703369)
# (76, 'Lyapunov Risk=', 6.939555644989014)
# (77, 'Lyapunov Risk=', 6.934107303619385)
# (78, 'Lyapunov Risk=', 6.928040981292725)
# (79, 'Lyapunov Risk=', 6.9227142333984375)
# (80, 'Lyapunov Risk=', 6.918410301208496)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.9823388267758031978, -0.9723388267758031889]
# x2 : [3.944218750000000995, 3.954218750000000782]
# ==============================
# (81, 'Lyapunov Risk=', 6.8133931159973145)
# (82, 'Lyapunov Risk=', 6.808027267456055)
# (83, 'Lyapunov Risk=', 6.8030924797058105)
# (84, 'Lyapunov Risk=', 6.798694133758545)
# (85, 'Lyapunov Risk=', 6.793935775756836)
# (86, 'Lyapunov Risk=', 6.788970947265625)
# (87, 'Lyapunov Risk=', 6.784284591674805)
# (88, 'Lyapunov Risk=', 6.779574871063232)
# (89, 'Lyapunov Risk=', 6.774860858917236)
# (90, 'Lyapunov Risk=', 6.770131587982178)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.6074652146989306667, -0.5974652146989306578]
# x2 : [2.221562500000000551, 2.231562500000000338]
# ==============================
# (91, 'Lyapunov Risk=', 6.823991298675537)
# (92, 'Lyapunov Risk=', 6.818828582763672)
# (93, 'Lyapunov Risk=', 6.813567638397217)
# (94, 'Lyapunov Risk=', 6.808196067810059)
# (95, 'Lyapunov Risk=', 6.802806377410889)
# (96, 'Lyapunov Risk=', 6.797262668609619)
# (97, 'Lyapunov Risk=', 6.791582107543945)
# (98, 'Lyapunov Risk=', 6.785859107971191)
# (99, 'Lyapunov Risk=', 6.780142784118652)
# (100, 'Lyapunov Risk=', 6.774465084075928)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-1.509321998547981547, -1.500000000000000222]
# x2 : [4.922490754283955994, 4.932490754283955781]
# ==============================
# (101, 'Lyapunov Risk=', 6.6916117668151855)
# (102, 'Lyapunov Risk=', 6.686018943786621)
# (103, 'Lyapunov Risk=', 6.680390357971191)
# (104, 'Lyapunov Risk=', 6.674755096435547)
# (105, 'Lyapunov Risk=', 6.669092655181885)
# (106, 'Lyapunov Risk=', 6.663349151611328)
# (107, 'Lyapunov Risk=', 6.657630920410156)
# (108, 'Lyapunov Risk=', 6.6518049240112305)
# (109, 'Lyapunov Risk=', 6.645932197570801)
# (110, 'Lyapunov Risk=', 6.640069484710693)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-1.513555547539109369, -1.503555547539109583]
# x2 : [5.312695203726270243, 5.32269520372627003]
# ==============================
# (111, 'Lyapunov Risk=', 6.589686393737793)
# (112, 'Lyapunov Risk=', 6.5841851234436035)
# (113, 'Lyapunov Risk=', 6.578735828399658)
# (114, 'Lyapunov Risk=', 6.573367595672607)
# (115, 'Lyapunov Risk=', 6.567925453186035)
# (116, 'Lyapunov Risk=', 6.562567234039307)
# (117, 'Lyapunov Risk=', 6.557010173797607)
# (118, 'Lyapunov Risk=', 6.55150842666626)
# (119, 'Lyapunov Risk=', 6.546072959899902)
# (120, 'Lyapunov Risk=', 6.540323734283447)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-5.985732892460227106, -5.984517339280457371]
# x2 : [0.2029747040119778689, 0.2055118878121275916]
# ==============================
# (121, 'Lyapunov Risk=', 6.509384632110596)
# (122, 'Lyapunov Risk=', 6.495104789733887)
# (123, 'Lyapunov Risk=', 6.49614953994751)
# (124, 'Lyapunov Risk=', 6.4939045906066895)
# (125, 'Lyapunov Risk=', 6.485686779022217)
# (126, 'Lyapunov Risk=', 6.4741668701171875)
# (127, 'Lyapunov Risk=', 6.464672088623047)
# (128, 'Lyapunov Risk=', 6.457217216491699)
# (129, 'Lyapunov Risk=', 6.4583916664123535)
# (130, 'Lyapunov Risk=', 6.452328681945801)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.4086432324614850953, -0.3986432324614850864]
# x2 : [1.326328570150740571, 1.336328570150740358]
# ==============================
# (131, 'Lyapunov Risk=', 6.631213188171387)
# (132, 'Lyapunov Risk=', 6.6247639656066895)
# (133, 'Lyapunov Risk=', 6.618300437927246)
# (134, 'Lyapunov Risk=', 6.6116623878479)
# (135, 'Lyapunov Risk=', 6.604804515838623)
# (136, 'Lyapunov Risk=', 6.597716808319092)
# (137, 'Lyapunov Risk=', 6.590392112731934)
# (138, 'Lyapunov Risk=', 6.582840919494629)
# (139, 'Lyapunov Risk=', 6.575015068054199)
# (140, 'Lyapunov Risk=', 6.566971302032471)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.1097123389205162391, -0.09971233892051623027]
# x2 : [0.5217048507572324967, 0.5317048507572325056]
# ==============================
# (141, 'Lyapunov Risk=', 6.924576282501221)
# (142, 'Lyapunov Risk=', 6.915141582489014)
# (143, 'Lyapunov Risk=', 6.905326843261719)
# (144, 'Lyapunov Risk=', 6.89514684677124)
# (145, 'Lyapunov Risk=', 6.884635925292969)
# (146, 'Lyapunov Risk=', 6.873801231384277)
# (147, 'Lyapunov Risk=', 6.862657070159912)
# (148, 'Lyapunov Risk=', 6.8512163162231445)
# (149, 'Lyapunov Risk=', 6.839859485626221)
# (150, 'Lyapunov Risk=', 6.828097820281982)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.1089290825808838514, -0.09892908258088384255]
# x2 : [0.5217467767849066629, 0.5317467767849066718]
# ==============================
# (151, 'Lyapunov Risk=', 7.156503677368164)
# (152, 'Lyapunov Risk=', 7.143145561218262)
# (153, 'Lyapunov Risk=', 7.129055023193359)
# (154, 'Lyapunov Risk=', 7.114212989807129)
# (155, 'Lyapunov Risk=', 7.09860897064209)
# (156, 'Lyapunov Risk=', 7.082342147827148)
# (157, 'Lyapunov Risk=', 7.06764030456543)
# (158, 'Lyapunov Risk=', 7.0501909255981445)
# (159, 'Lyapunov Risk=', 7.034244060516357)
# (160, 'Lyapunov Risk=', 7.017744064331055)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [1.780622676700700513, 1.783321967531370067]
# x2 : [-5.088477832761189035, -5.084752146416758656]
# ==============================
# (161, 'Lyapunov Risk=', 6.9708428382873535)
# (162, 'Lyapunov Risk=', 6.955507755279541)
# (163, 'Lyapunov Risk=', 6.940574645996094)
# (164, 'Lyapunov Risk=', 6.925055980682373)
# (165, 'Lyapunov Risk=', 6.9090962409973145)
# (166, 'Lyapunov Risk=', 6.8927226066589355)
# (167, 'Lyapunov Risk=', 6.876031398773193)
# (168, 'Lyapunov Risk=', 6.861100196838379)
# (169, 'Lyapunov Risk=', 6.844182014465332)
# (170, 'Lyapunov Risk=', 6.8285627365112305)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.1573437500000000322, -0.1473437500000000233]
# x2 : [0.5161476940670223224, 0.5261476940670223312]
# ==============================
# (171, 'Lyapunov Risk=', 7.090911865234375)
# (172, 'Lyapunov Risk=', 7.071982383728027)
# (173, 'Lyapunov Risk=', 7.052405834197998)
# (174, 'Lyapunov Risk=', 7.032655715942383)
# (175, 'Lyapunov Risk=', 7.012545585632324)
# (176, 'Lyapunov Risk=', 6.992681503295898)
# (177, 'Lyapunov Risk=', 6.9731035232543945)
# (178, 'Lyapunov Risk=', 6.952930450439453)
# (179, 'Lyapunov Risk=', 6.932590484619141)
# (180, 'Lyapunov Risk=', 6.913418769836426)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-5.842811402599402015, -5.842423547022136177]
# x2 : [1.362726102062943756, 1.363155269723244079]
# ==============================
# (181, 'Lyapunov Risk=', 6.869648456573486)
# (182, 'Lyapunov Risk=', 6.84241247177124)
# (183, 'Lyapunov Risk=', 6.825230121612549)
# (184, 'Lyapunov Risk=', 6.8046793937683105)
# (185, 'Lyapunov Risk=', 6.782918453216553)
# (186, 'Lyapunov Risk=', 6.762145519256592)
# (187, 'Lyapunov Risk=', 6.743434429168701)
# (188, 'Lyapunov Risk=', 6.7246270179748535)
# (189, 'Lyapunov Risk=', 6.705259323120117)
# (190, 'Lyapunov Risk=', 6.685351371765137)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [1.506789405620137412, 1.507255157012731495]
# x2 : [-5.807717769236977468, -5.807302874937603221]
# ==============================
# (191, 'Lyapunov Risk=', 6.752874374389648)
# (192, 'Lyapunov Risk=', 6.738163471221924)
# (193, 'Lyapunov Risk=', 6.717601776123047)
# (194, 'Lyapunov Risk=', 6.701282501220703)
# (195, 'Lyapunov Risk=', 6.684205532073975)
# (196, 'Lyapunov Risk=', 6.665576457977295)
# (197, 'Lyapunov Risk=', 6.645236015319824)
# (198, 'Lyapunov Risk=', 6.624305248260498)
# (199, 'Lyapunov Risk=', 6.607666969299316)
# (200, 'Lyapunov Risk=', 6.590645790100098)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-1.303710937500000222, -1.300781250000000222]
# x2 : [5.846410271397505021, 5.851855342690381434]
# ==============================
# (201, 'Lyapunov Risk=', 6.6540021896362305)
# (202, 'Lyapunov Risk=', 6.63875675201416)
# (203, 'Lyapunov Risk=', 6.622025489807129)
# (204, 'Lyapunov Risk=', 6.601069450378418)
# (205, 'Lyapunov Risk=', 6.58030366897583)
# (206, 'Lyapunov Risk=', 6.5609822273254395)
# (207, 'Lyapunov Risk=', 6.543219089508057)
# (208, 'Lyapunov Risk=', 6.524356842041016)
# (209, 'Lyapunov Risk=', 6.503382682800293)
# (210, 'Lyapunov Risk=', 6.4820451736450195)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.7532167506553872904, -0.7500226097837748851]
# x2 : [2.695312500000000444, 2.701171875000000444]
# ==============================
# (211, 'Lyapunov Risk=', 6.402404308319092)
# (212, 'Lyapunov Risk=', 6.383531093597412)
# (213, 'Lyapunov Risk=', 6.36519193649292)
# (214, 'Lyapunov Risk=', 6.346612453460693)
# (215, 'Lyapunov Risk=', 6.327645778656006)
# (216, 'Lyapunov Risk=', 6.309167385101318)
# (217, 'Lyapunov Risk=', 6.2914299964904785)
# (218, 'Lyapunov Risk=', 6.273314476013184)
# (219, 'Lyapunov Risk=', 6.256388187408447)
# (220, 'Lyapunov Risk=', 6.239765644073486)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.3099765805747176639, -0.3009726546283665871]
# x2 : [1.078984375000000329, 1.088984375000000115]
# ==============================
# (221, 'Lyapunov Risk=', 6.318282604217529)
# (222, 'Lyapunov Risk=', 6.300891876220703)
# (223, 'Lyapunov Risk=', 6.28300142288208)
# (224, 'Lyapunov Risk=', 6.264749050140381)
# (225, 'Lyapunov Risk=', 6.246890068054199)
# (226, 'Lyapunov Risk=', 6.229901313781738)
# (227, 'Lyapunov Risk=', 6.212738037109375)
# (228, 'Lyapunov Risk=', 6.195106029510498)
# (229, 'Lyapunov Risk=', 6.177058696746826)
# (230, 'Lyapunov Risk=', 6.1587982177734375)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.1092515085928135177, -0.09925150859281350879]
# x2 : [0.5144758277675055558, 0.5244758277675055647]
# ==============================
# (231, 'Lyapunov Risk=', 6.309262752532959)
# (232, 'Lyapunov Risk=', 6.288877010345459)
# (233, 'Lyapunov Risk=', 6.269154071807861)
# (234, 'Lyapunov Risk=', 6.249567985534668)
# (235, 'Lyapunov Risk=', 6.230405807495117)
# (236, 'Lyapunov Risk=', 6.210448265075684)
# (237, 'Lyapunov Risk=', 6.191051959991455)
# (238, 'Lyapunov Risk=', 6.1719255447387695)
# (239, 'Lyapunov Risk=', 6.153635025024414)
# (240, 'Lyapunov Risk=', 6.135422706604004)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.1242512160348364925, -0.1174722029386103678]
# x2 : [0.5282631414363193612, 0.53826314143631937]
# ==============================
# (241, 'Lyapunov Risk=', 6.25416898727417)
# (242, 'Lyapunov Risk=', 6.233448505401611)
# (243, 'Lyapunov Risk=', 6.212782859802246)
# (244, 'Lyapunov Risk=', 6.192344665527344)
# (245, 'Lyapunov Risk=', 6.172250747680664)
# (246, 'Lyapunov Risk=', 6.152294158935547)
# (247, 'Lyapunov Risk=', 6.1326985359191895)
# (248, 'Lyapunov Risk=', 6.113443374633789)
# (249, 'Lyapunov Risk=', 6.0944437980651855)
# (250, 'Lyapunov Risk=', 6.075540065765381)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.1245302065592224366, -0.1176166972976988856]
# x2 : [0.533273330004749524, 0.5403594569415368642]
# ==============================
# (251, 'Lyapunov Risk=', 6.165192604064941)
# (252, 'Lyapunov Risk=', 6.143945217132568)
# (253, 'Lyapunov Risk=', 6.12256383895874)
# (254, 'Lyapunov Risk=', 6.101107120513916)
# (255, 'Lyapunov Risk=', 6.079484462738037)
# (256, 'Lyapunov Risk=', 6.0575385093688965)
# (257, 'Lyapunov Risk=', 6.035309314727783)
# (258, 'Lyapunov Risk=', 6.012657165527344)
# (259, 'Lyapunov Risk=', 5.989147663116455)
# (260, 'Lyapunov Risk=', 5.964563369750977)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.05564569631428881863, -0.04564569631428882363]
# x2 : [0.5241243523800190873, 0.5341243523800190962]
# ==============================
# (261, 'Lyapunov Risk=', 6.029120445251465)
# (262, 'Lyapunov Risk=', 6.002884387969971)
# (263, 'Lyapunov Risk=', 5.975587844848633)
# (264, 'Lyapunov Risk=', 5.946793556213379)
# (265, 'Lyapunov Risk=', 5.916933059692383)
# (266, 'Lyapunov Risk=', 5.886115074157715)
# (267, 'Lyapunov Risk=', 5.854376316070557)
# (268, 'Lyapunov Risk=', 5.821198463439941)
# (269, 'Lyapunov Risk=', 5.7871270179748535)
# (270, 'Lyapunov Risk=', 5.751532077789307)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.1565876609556311472, -0.1494270066630787597]
# x2 : [0.7321620494688090286, 0.7410810247344046253]
# ==============================
# (271, 'Lyapunov Risk=', 5.761460304260254)
# (272, 'Lyapunov Risk=', 5.723428249359131)
# (273, 'Lyapunov Risk=', 5.683546543121338)
# (274, 'Lyapunov Risk=', 5.645268440246582)
# (275, 'Lyapunov Risk=', 5.605838775634766)
# (276, 'Lyapunov Risk=', 5.5663957595825195)
# (277, 'Lyapunov Risk=', 5.527245044708252)
# (278, 'Lyapunov Risk=', 5.489575386047363)
# (279, 'Lyapunov Risk=', 5.458305358886719)
# (280, 'Lyapunov Risk=', 5.429406642913818)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.1513292961220007449, -0.1444464026402633439]
# x2 : [0.7323961489576400474, 0.7411980744788200237]
# ==============================
# (281, 'Lyapunov Risk=', 5.4274725914001465)
# (282, 'Lyapunov Risk=', 5.3959760665893555)
# (283, 'Lyapunov Risk=', 5.364740371704102)
# (284, 'Lyapunov Risk=', 5.334807395935059)
# (285, 'Lyapunov Risk=', 5.306095600128174)
# (286, 'Lyapunov Risk=', 5.277707576751709)
# (287, 'Lyapunov Risk=', 5.249811172485352)
# (288, 'Lyapunov Risk=', 5.223770618438721)
# (289, 'Lyapunov Risk=', 5.197051048278809)
# (290, 'Lyapunov Risk=', 5.169878959655762)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.05317705282813928874, -0.04317705282813929374]
# x2 : [0.5242337324943253662, 0.5342337324943253751]
# ==============================
# (291, 'Lyapunov Risk=', 5.170862197875977)
# (292, 'Lyapunov Risk=', 5.149997711181641)
# (293, 'Lyapunov Risk=', 5.125445365905762)
# (294, 'Lyapunov Risk=', 5.111181259155273)
# (295, 'Lyapunov Risk=', 5.080249786376953)
# (296, 'Lyapunov Risk=', 5.066631317138672)
# (297, 'Lyapunov Risk=', 5.038623809814453)
# (298, 'Lyapunov Risk=', 5.018533229827881)
# (299, 'Lyapunov Risk=', 4.991840362548828)
# (300, 'Lyapunov Risk=', 4.976197719573975)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.04601562500000000444, -0.03601562500000000944]
# x2 : [0.5247190639723556815, 0.5347190639723556904]
# ==============================
# (301, 'Lyapunov Risk=', 4.963245391845703)
# (302, 'Lyapunov Risk=', 4.9447021484375)
# (303, 'Lyapunov Risk=', 4.921287536621094)
# (304, 'Lyapunov Risk=', 4.918063163757324)
# (305, 'Lyapunov Risk=', 4.886592864990234)
# (306, 'Lyapunov Risk=', 4.8735880851745605)
# (307, 'Lyapunov Risk=', 4.851985931396484)
# (308, 'Lyapunov Risk=', 4.8363752365112305)
# (309, 'Lyapunov Risk=', 4.806105613708496)
# (310, 'Lyapunov Risk=', 4.791688442230225)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-2.532714843750000444, -2.531250000000000444]
# x2 : [5.412693982289024319, 5.414638985600629617]
# ==============================
# (311, 'Lyapunov Risk=', 4.7732439041137695)
# (312, 'Lyapunov Risk=', 4.753516674041748)
# (313, 'Lyapunov Risk=', 4.7362494468688965)
# (314, 'Lyapunov Risk=', 4.719109058380127)
# (315, 'Lyapunov Risk=', 4.7045674324035645)
# (316, 'Lyapunov Risk=', 4.681929588317871)
# (317, 'Lyapunov Risk=', 4.677135944366455)
# (318, 'Lyapunov Risk=', 4.651401042938232)
# (319, 'Lyapunov Risk=', 4.646790027618408)
# (320, 'Lyapunov Risk=', 4.6176557540893555)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.03515625000000000694, -0.02929687500000000694]
# x2 : [0.6451797284707685431, 0.6517309954413454953]
# ==============================
# (321, 'Lyapunov Risk=', 4.5948405265808105)
# (322, 'Lyapunov Risk=', 4.5713677406311035)
# (323, 'Lyapunov Risk=', 4.566387176513672)
# (324, 'Lyapunov Risk=', 4.540093421936035)
# (325, 'Lyapunov Risk=', 4.533636093139648)
# (326, 'Lyapunov Risk=', 4.516810417175293)
# (327, 'Lyapunov Risk=', 4.49673318862915)
# (328, 'Lyapunov Risk=', 4.486810684204102)
# (329, 'Lyapunov Risk=', 4.470998287200928)
# (330, 'Lyapunov Risk=', 4.461278915405273)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-2.25406472162240723, -2.252038053351316904]
# x2 : [5.514676915187001427, 5.516937484241037026]
# ==============================
# (331, 'Lyapunov Risk=', 4.44246244430542)
# (332, 'Lyapunov Risk=', 4.43756628036499)
# (333, 'Lyapunov Risk=', 4.414097309112549)
# (334, 'Lyapunov Risk=', 4.406340599060059)
# (335, 'Lyapunov Risk=', 4.394321918487549)
# (336, 'Lyapunov Risk=', 4.373498439788818)
# (337, 'Lyapunov Risk=', 4.368523597717285)
# (338, 'Lyapunov Risk=', 4.3482985496521)
# (339, 'Lyapunov Risk=', 4.340097427368164)
# (340, 'Lyapunov Risk=', 4.329519271850586)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-1.500366210937500444, -1.500000000000000222]
# x2 : [-5.809475019311125976, -5.808789112323989201]
# ==============================
# (341, 'Lyapunov Risk=', 4.383569240570068)
# (342, 'Lyapunov Risk=', 4.362281799316406)
# (343, 'Lyapunov Risk=', 4.3384599685668945)
# (344, 'Lyapunov Risk=', 4.330292224884033)
# (345, 'Lyapunov Risk=', 4.319334030151367)
# (346, 'Lyapunov Risk=', 4.308896064758301)
# (347, 'Lyapunov Risk=', 4.296451568603516)
# (348, 'Lyapunov Risk=', 4.285750865936279)
# (349, 'Lyapunov Risk=', 4.274223327636719)
# (350, 'Lyapunov Risk=', 4.264007568359375)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-2.342590638883333298, -2.340216519937607043]
# x2 : [5.268274888297129976, 5.270535457351165576]
# ==============================
# (351, 'Lyapunov Risk=', 4.228728771209717)
# (352, 'Lyapunov Risk=', 4.214633464813232)
# (353, 'Lyapunov Risk=', 4.2020087242126465)
# (354, 'Lyapunov Risk=', 4.19018030166626)
# (355, 'Lyapunov Risk=', 4.180427074432373)
# (356, 'Lyapunov Risk=', 4.1691813468933105)
# (357, 'Lyapunov Risk=', 4.166440010070801)
# (358, 'Lyapunov Risk=', 4.156501293182373)
# (359, 'Lyapunov Risk=', 4.1456756591796875)
# (360, 'Lyapunov Risk=', 4.134157180786133)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.1415095335584430347, 0.1515095335584430436]
# x2 : [-0.500389549032561276, -0.4903895490325613227]
# ==============================
# (361, 'Lyapunov Risk=', 4.110007286071777)
# (362, 'Lyapunov Risk=', 4.1042351722717285)
# (363, 'Lyapunov Risk=', 4.091579914093018)
# (364, 'Lyapunov Risk=', 4.084765911102295)
# (365, 'Lyapunov Risk=', 4.0763750076293945)
# (366, 'Lyapunov Risk=', 4.064483165740967)
# (367, 'Lyapunov Risk=', 4.059603214263916)
# (368, 'Lyapunov Risk=', 4.045264720916748)
# (369, 'Lyapunov Risk=', 4.040499687194824)
# (370, 'Lyapunov Risk=', 4.029545783996582)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.1374365791505763046, 0.1408820385388838692]
# x2 : [-0.4833447478606428538, -0.4797418589378337761]
# ==============================
# (371, 'Lyapunov Risk=', 4.004495620727539)
# (372, 'Lyapunov Risk=', 3.9919850826263428)
# (373, 'Lyapunov Risk=', 3.984131097793579)
# (374, 'Lyapunov Risk=', 3.9785587787628174)
# (375, 'Lyapunov Risk=', 3.9677302837371826)
# (376, 'Lyapunov Risk=', 3.960303544998169)
# (377, 'Lyapunov Risk=', 3.9523894786834717)
# (378, 'Lyapunov Risk=', 3.945159435272217)
# (379, 'Lyapunov Risk=', 3.93666934967041)
# (380, 'Lyapunov Risk=', 3.9283783435821533)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-2.167109375000000338, -2.157109375000000551]
# x2 : [5.523877129496184146, 5.533877129496183933]
# ==============================
# (381, 'Lyapunov Risk=', 3.912712574005127)
# (382, 'Lyapunov Risk=', 3.903860330581665)
# (383, 'Lyapunov Risk=', 3.8947412967681885)
# (384, 'Lyapunov Risk=', 3.88926362991333)
# (385, 'Lyapunov Risk=', 3.8829238414764404)
# (386, 'Lyapunov Risk=', 3.8749020099639893)
# (387, 'Lyapunov Risk=', 3.8678696155548096)
# (388, 'Lyapunov Risk=', 3.860997200012207)
# (389, 'Lyapunov Risk=', 3.8533151149749756)
# (390, 'Lyapunov Risk=', 3.8501977920532227)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-2.167109375000000338, -2.157109375000000551]
# x2 : [5.523877129496184146, 5.533877129496183933]
# ==============================
# (391, 'Lyapunov Risk=', 3.828953504562378)
# (392, 'Lyapunov Risk=', 3.822031259536743)
# (393, 'Lyapunov Risk=', 3.8126914501190186)
# (394, 'Lyapunov Risk=', 3.806110143661499)
# (395, 'Lyapunov Risk=', 3.798611879348755)
# (396, 'Lyapunov Risk=', 3.798466444015503)
# (397, 'Lyapunov Risk=', 3.7911112308502197)
# (398, 'Lyapunov Risk=', 3.7854206562042236)
# (399, 'Lyapunov Risk=', 3.7765698432922363)
# (400, 'Lyapunov Risk=', 3.7708206176757812)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-2.063964843750000444, -2.062500000000000444]
# x2 : [5.621731063570308606, 5.623536225987946224]
# ==============================
# (401, 'Lyapunov Risk=', 3.756504535675049)
# (402, 'Lyapunov Risk=', 3.7504842281341553)
# (403, 'Lyapunov Risk=', 3.7439329624176025)
# (404, 'Lyapunov Risk=', 3.7383737564086914)
# (405, 'Lyapunov Risk=', 3.7296383380889893)
# (406, 'Lyapunov Risk=', 3.72628116607666)
# (407, 'Lyapunov Risk=', 3.717179775238037)
# (408, 'Lyapunov Risk=', 3.7117226123809814)
# (409, 'Lyapunov Risk=', 3.7057888507843018)
# (410, 'Lyapunov Risk=', 3.698866128921509)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-1.968750000000000444, -1.967285156250000444]
# x2 : [5.623142457305847941, 5.625456520950792516]
# ==============================
# (411, 'Lyapunov Risk=', 3.6844122409820557)
# (412, 'Lyapunov Risk=', 3.6785953044891357)
# (413, 'Lyapunov Risk=', 3.6725940704345703)
# (414, 'Lyapunov Risk=', 3.6677238941192627)
# (415, 'Lyapunov Risk=', 3.6626858711242676)
# (416, 'Lyapunov Risk=', 3.657015800476074)
# (417, 'Lyapunov Risk=', 3.6522397994995117)
# (418, 'Lyapunov Risk=', 3.647165298461914)
# (419, 'Lyapunov Risk=', 3.6417369842529297)
# (420, 'Lyapunov Risk=', 3.635631799697876)
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.2759067043144699527, -0.2738843921576223917]
# x2 : [0.4330516146406998557, 0.434295400026502576]
# ==============================
# (421, 'Lyapunov Risk=', 3.6196789741516113)
# (422, 'Lyapunov Risk=', 3.6173019409179688)
# (423, 'Lyapunov Risk=', 3.6098194122314453)
# (424, 'Lyapunov Risk=', 3.605344772338867)
# (425, 'Lyapunov Risk=', 3.5997674465179443)
# (426, 'Lyapunov Risk=', 3.5971572399139404)
# (427, 'Lyapunov Risk=', 3.589878797531128)
# (428, 'Lyapunov Risk=', 3.585435152053833)
# (429, 'Lyapunov Risk=', 3.5812630653381348)
# (430, 'Lyapunov Risk=', 3.578098773956299)
# ===========Verifying==========
# Satisfy conditions!!
# (<Expression "tanh((0.47052764892578125 - 0.36160281300544739 * tanh((-0.75011157989501953 + 0.0088593903928995132 * x1 - 0.0036623133346438408 * x2)) + 0.79846572875976562 * tanh((-0.6316143274307251 + 0.73739403486251831 * x1 - 0.0083910385146737099 * x2)) + 0.13357226550579071 * tanh((-0.57977020740509033 - 0.31221801042556763 * x1 - 0.1601211279630661 * x2)) - 0.94644665718078613 * tanh((0.81671983003616333 + 0.92968451976776123 * x1 - 0.01118092518299818 * x2)) - 0.16966792941093445 * tanh((1.0393475294113159 - 0.6808173656463623 * x1 - 0.21255317330360413 * x2)) + 0.93776065111160278 * tanh((1.1187564134597778 + 0.00042254151776432991 * x1 - 8.0787671322468668e-05 * x2))))">, ' is a Lyapunov function.')
# ==============================
#
#
# ('Total time: ', 25.51008701324463)
# ('Verified time: ', 0.6063435077667236)

# %% [markdown]
# ### Checking result with smaller epsilon

# %%
epsilon = -0.00001
start_ = timeit.default_timer() 
result = CheckLyapunov(vars_, f, V_learn, ball_lb, ball_ub, config, epsilon)
stop_ = timeit.default_timer() 

if (result): 
    print("Not a Lyapunov function. Found counterexample: ")
else:  
    print("Satisfy conditions with epsilon= ",epsilon)
    print(V_learn, " is a Lyapunov function.")
t += (stop_ - start_)
# Out:
# ('Satisfy conditions with epsilon= ', -1e-05)
# (<Expression "tanh((0.47052764892578125 - 0.36160281300544739 * tanh((-0.75011157989501953 + 0.0088593903928995132 * x1 - 0.0036623133346438408 * x2)) + 0.79846572875976562 * tanh((-0.6316143274307251 + 0.73739403486251831 * x1 - 0.0083910385146737099 * x2)) + 0.13357226550579071 * tanh((-0.57977020740509033 - 0.31221801042556763 * x1 - 0.1601211279630661 * x2)) - 0.94644665718078613 * tanh((0.81671983003616333 + 0.92968451976776123 * x1 - 0.01118092518299818 * x2)) - 0.16966792941093445 * tanh((1.0393475294113159 - 0.6808173656463623 * x1 - 0.21255317330360413 * x2)) + 0.93776065111160278 * tanh((1.1187564134597778 + 0.00042254151776432991 * x1 - 8.0787671322468668e-05 * x2))))">, ' is a Lyapunov function.')
